# %% [markdown]
# # Route Prediction
#
# #### Motivation:
# This module focuses on leveraging human knowledge to get the best route. At a  given time due to certain circumstances (like rush hour) it is possible that a certain route may be faster than a route shown on the map. People who travel at those times or people who are residents of those areas have more knowledge about which route should be taken at what time. If every person entered which path to be taken based on their experience we could create a database that will help us to predict which path should be taken.
#
# #### Dataset:
# The format of the dataset is as follows:
#
# - uid: the unique id of the the person making the entry.
# - rating: the rating of the person adds weightage to the validity of the claim (this follows a rating system similar to that of cab companies) and it ranges from 0-5.
# - metro: 0 indicates the area is a metro and 1 indicates it isn't a metro city.
# - country: determines in which country the route is. Currently there are 3 countries *Germany*, *England* and *Russia*.
# - startTime: the begining of the time frame when the particular route should be used.
# - endTime: the ending of the time frame when the particular route should be used.
# - oldRoute: the old route given by the map.
# - newRoute: the new route that should be taken.
# - mapUsed: 1 indicates that the map is used whereas 0 indicates that the map is not used

# %% [markdown]
# Importing all the required packages

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import numpy as np
import pandas as pd
from sklearn import datasets, svm, cross_validation, tree, preprocessing, metrics
import sklearn.ensemble as ske
import tensorflow as tf
from tensorflow.contrib import learn as skflow
# Out:
# C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
route_df = pd.read_excel('route.xls', index_col=None, na_values=['NA'])

# %% [markdown]
# Let's look at the data

# %%
route_df.head()
# Out:
#    uid                                  name  metro  country    rating  \
# 0  411  Wick George Dennick (Mary Hitchcock)      0  England  0.016011
# 1  136                  Bowerman Elsie Edith      0  England  0.049281
# 2  324                        Partner Austen      0  England  0.169474
# 3  281           Leader, Dr. Alice (Farnham)      0  England  0.176204
# 4  205                     Evans Edith Corse      0  England  0.284004
#
#    startTime  endTime oldRoute newRoute  mapUsed
# 0       16.0     17.3       R3       R3        1
# 1       16.0     17.3       R3       R3        1
# 2       16.0     17.3       R3       R3        1
# 3       16.0     17.3       R3       R3        1
# 4       16.0     17.3       R3       R4        0

# %% [markdown]
# Let's look at what percentage of the drivers are using the map?

# %%
route_df['mapUsed'].mean()
# Out:
# 0.474

# %% [markdown]
# 47% of the drivers are following the map.
#
# Let's see the groupings by the country

# %%
route_df.groupby('country').mean()
# Out:
#                 uid     metro    rating  startTime    endTime   mapUsed
# country
# England  348.426036  0.502959  2.403062  16.653846  18.500592  0.455621
# Germany  354.237179  0.506410  2.568901  16.654487  18.506410  0.480769
# Russia   349.171429  0.514286  2.487564  14.640000  17.000000  0.485714

# %% [markdown]
# Approximately 45-48% ofthe drivers are using the map in each country and approximately half of the entries are made in metro cities. Let's plot this values to get batter understanding ofthe data

# %%
country_metro_grouping = route_df.groupby(['country','metro']).mean()
country_metro_grouping
# Out:
#                       uid    rating  startTime    endTime   mapUsed
# country metro
# England 0      346.690476  2.526212       16.0  17.300000  0.464286
#         1      350.141176  2.281361       17.3  19.687059  0.447059
# Germany 0      373.961039  2.515311       16.3  18.000000  0.441558
#         1      335.012658  2.621135       17.0  19.000000  0.518987
# Russia  0      353.611765  2.548772       15.0  17.000000  0.435294
#         1      344.977778  2.429756       14.3  17.000000  0.533333

# %%
country_metro_grouping['mapUsed'].plot.bar()

# %% [markdown]
# 1 signifies that it is a metro
#
# Let's visualize the data based on the rating of the drivers

# %%
group_by_age = pd.cut(route_df["rating"], np.arange(0, 6, 1))
rating_grouping = route_df.groupby(group_by_age).mean()
rating_grouping['mapUsed'].plot.bar()

# %% [markdown]
# Most of the drivers are between the range of 1-2
#
# Let's check for missing values by doing a count on each of the columns

# %%
route_df.count()
# Out:
# uid          500
# name         500
# metro        500
# country      500
# rating       500
# startTime    500
# endTime      500
# oldRoute     500
# newRoute     500
# mapUsed      500
# dtype: int64

# %% [markdown]
# There are no missing values. However if there are missing values we can deal with them in the following way:
#
# 1. If the column (col1) from which the values are missing is an important factor, we need to drop the rows containing those values.
# ```python
#  route_df["col1"] = route_df["col1"].fillna("NA") #first fill the columns with value NA
#  route_df = route_df.dropna() #drop the rows with missing values
# ```
#
# 2. If the column(col2,col3) is not an important factor, we can drop the column
# ```python
# route_df = route_df.drop(['col2','col3'], axis=1) #drop the columns
# ```
#
#
# Now for the preprocessing

# %%
def preprocess_route_df(df):
    processed_df = df.copy()
    le = preprocessing.LabelEncoder()
    processed_df.country = le.fit_transform(processed_df.country)
    processed_df.oldRoute = le.fit_transform(processed_df.oldRoute)
    processed_df.newRoute = le.fit_transform(processed_df.newRoute)
    processed_df = processed_df.drop(['name','uid'],axis=1)
    return processed_df

# %% [markdown]
# What we are basically doing here is processing the data to produce numeric labels for the string data
#
# Let's look at the data again

# %%
processed_df = preprocess_route_df(route_df)
processed_df
# Out:
#      metro  country    rating  startTime  endTime  oldRoute  newRoute  mapUsed
# 0        0        0  0.016011       16.0     17.3         2         5        1
# 1        0        0  0.049281       16.0     17.3         2         5        1
# 2        0        0  0.169474       16.0     17.3         2         5        1
# 3        0        0  0.176204       16.0     17.3         2         5        1
# 4        0        0  0.284004       16.0     17.3         2         6        0
# 5        0        0  0.614796       16.0     17.3         2         5        1
# 6        0        0  0.633776       16.0     17.3         2         6        0
# 7        0        0  0.712780       16.0     17.3         2         5        1
# 8        0        0  0.787276       16.0     17.3         2         5        1
# 9        0        0  0.822311       16.0     17.3         2         5        1
# 10       0        0  0.829835       16.0     17.3         2         6        0
# 11       0        0  0.868657       16.0     17.3         2         5        1
# 12       0        0  0.919828       16.0     17.3         2         5        1
# 13       0        0  1.007483       16.0     17.3         2         5        1
# 14       0        0  1.103939       16.0     17.3         2         5        1
# 15       0        0  1.129389       16.0     17.3         2         5        1
# 16       0        0  1.136403       16.0     17.3         2         5        1
# 17       0        0  1.386064       16.0     17.3         2         5        1
# 18       0        0  1.414845       16.0     17.3         2         5        1
# 19       0        0  1.444325       16.0     17.3         2         5        1
# 20       0        0  1.472965       16.0     17.3         2         5        1
# 21       0        0  1.481402       16.0     17.3         2         5        1
# 22       0        0  1.483025       16.0     17.3         2         5        1
# 23       0        0  1.521224       16.0     17.3         2         5        1
# 24       0        0  1.680886       16.0     17.3         2         5        1
# 25       0        0  1.737758       16.0     17.3         2         5        1
# 26       0        0  1.913498       16.0     17.3         2         5        1
# 27       0        0  1.924166       16.0     17.3         2         5        1
# 28       0        0  1.934866       16.0     17.3         2         5        1
# 29       0        0  2.015483       16.0     17.3         2         5        1
# ..     ...      ...       ...        ...      ...       ...       ...      ...
# 470      1        2  3.311774       14.3     17.0         1         3        0
# 471      1        2  3.357713       14.3     17.0         1         3        0
# 472      1        2  3.492864       14.3     17.0         1         3        0
# 473      1        2  3.494193       14.3     17.0         1         3        0
# 474      1        2  3.547185       14.3     17.0         1         3        0
# 475      1        2  3.702069       14.3     17.0         1         3        0
# 476      1        2  3.742632       14.3     17.0         1         3        0
# 477      1        2  3.745421       14.3     17.0         1         3        0
# 478      1        2  3.795905       14.3     17.0         1         3        0
# 479      1        2  3.825862       14.3     17.0         1         3        0
# 480      1        2  4.009469       14.3     17.0         1         3        0
# 481      1        2  4.067659       14.3     17.0         1         3        0
# 482      1        2  4.068963       14.3     17.0         1         3        0
# 483      1        2  4.289566       14.3     17.0         1         3        0
# 484      1        2  4.328859       14.3     17.0         1         3        0
# 485      1        2  4.364985       14.3     17.0         1         3        0
# 486      1        2  4.369504       14.3     17.0         1         3        0
# 487      1        2  4.410162       14.3     17.0         1         3        0
# 488      1        2  4.419123       14.3     17.0         1         3        0
# 489      1        2  4.523683       14.3     17.0         1         3        0
# 490      1        2  4.597265       14.3     17.0         1         3        0
# 491      1        2  4.626939       14.3     17.0         1         3        0
# 492      1        2  4.700190       14.3     17.0         1         3        0
# 493      1        2  4.719667       14.3     17.0         1         3        0
# 494      1        2  4.736937       14.3     17.0         1         3        0
# 495      1        2  4.753774       14.3     17.0         1         3        0
# 496      1        2  4.881972       14.3     17.0         1         3        0
# 497      1        2  4.883764       14.3     17.0         1         3        0
# 498      1        2  4.967354       14.3     17.0         1         3        0
# 499      1        2  4.999186       14.3     17.0         1         3        0
#
# [500 rows x 8 columns]

# %% [markdown]
# *X* contains all the values besides whether the map was used or not and *y* contains the answer

# %%
X = processed_df.drop(['mapUsed'], axis=1).values
y = processed_df['mapUsed'].values

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,y,test_size=0.2)

# %% [markdown]
# decision tree

# %%
clf_dt = tree.DecisionTreeClassifier(max_depth=10)

# %%
clf_dt.fit (X_train, y_train)
clf_dt.score (X_test, y_test)
# Out:
# 0.98999999999999999

# %%
shuffle_validator = cross_validation.ShuffleSplit(len(X), n_iter=20, test_size=0.2, random_state=0)
def test_classifier(clf):
    scores = cross_validation.cross_val_score(clf, X, y, cv=shuffle_validator)
    print("Accuracy: %0.4f (+/- %0.2f)" % (scores.mean(), scores.std()))

# %%
test_classifier(clf_dt)
# Out:
# Accuracy: 0.9830 (+/- 0.01)

# %%
clf_rf = ske.RandomForestClassifier(n_estimators=50)
test_classifier(clf_rf)
# Out:
# Accuracy: 0.9960 (+/- 0.01)

# %%
clf_gb = ske.GradientBoostingClassifier(n_estimators=50)
test_classifier(clf_gb)
# Out:
# Accuracy: 0.9850 (+/- 0.01)

# %%
eclf = ske.VotingClassifier([('dt', clf_dt), ('rf', clf_rf), ('gb', clf_gb)])
test_classifier(eclf)
# Out:
# Accuracy: 0.9940 (+/- 0.01)

# %% [markdown]
# neural Network

# %%
#tf_clf_dnn = skflow.TensorFlowDNNClassifier(hidden_units=[20, 40, 20], n_classes=2, batch_size=256, steps=1000, learning_rate=0.05)
feature_columns = [tf.contrib.layers.real_valued_column("")]
tf_clf_dnn = skflow.DNNClassifier(feature_columns=feature_columns, hidden_units=[20, 40, 20], n_classes=2, model_dir="/tmp")
#tf_clf_dnn.evaluate(batch_size=256, steps=1000)
tf_clf_dnn.fit(X_train, y_train, steps=1000)
accuracy_score = tf_clf_dnn.evaluate(X_test, y_test,steps=1000)["accuracy"]
print("\nTest Accuracy: {0:f}\n".format(accuracy_score))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_is_chief': True, '_keep_checkpoint_max': 5, '_evaluation_master': '', '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000024F47F3A278>, '_task_id': 0, '_tf_random_seed': None, '_task_type': None, '_environment': 'local', '_num_ps_replicas': 0, '_save_checkpoints_secs': 600, '_model_dir': None, '_keep_checkpoint_every_n_hours': 10000, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_master': ''}
# WARNING:tensorflow:From <ipython-input-22-897a40b9cd7b>:5: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-22-897a40b9cd7b>:5: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# WARNING:tensorflow:From C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp\model.ckpt-7000
# INFO:tensorflow:Saving checkpoints for 7001 into /tmp\model.ckpt.
# INFO:tensorflow:step = 7001, loss = 0.00627551
# INFO:tensorflow:global_step/sec: 116.441
# INFO:tensorflow:step = 7101, loss = 0.00584711 (0.851 sec)
# INFO:tensorflow:global_step/sec: 120.342
# INFO:tensorflow:step = 7201, loss = 0.00545468 (0.832 sec)
# INFO:tensorflow:global_step/sec: 111.426
# INFO:tensorflow:step = 7301, loss = 0.00510196 (0.899 sec)
# INFO:tensorflow:global_step/sec: 116.856
# INFO:tensorflow:step = 7401, loss = 0.00479767 (0.854 sec)
# INFO:tensorflow:global_step/sec: 127.163
# INFO:tensorflow:step = 7501, loss = 0.00451944 (0.784 sec)
# INFO:tensorflow:global_step/sec: 128.25
# INFO:tensorflow:step = 7601, loss = 0.00427026 (0.780 sec)
# INFO:tensorflow:global_step/sec: 120.515
# INFO:tensorflow:step = 7701, loss = 0.00404619 (0.832 sec)
# INFO:tensorflow:global_step/sec: 123.451
# INFO:tensorflow:step = 7801, loss = 0.00384137 (0.806 sec)
# INFO:tensorflow:global_step/sec: 126.97
# INFO:tensorflow:step = 7901, loss = 0.00365138 (0.792 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into /tmp\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00348099.
# WARNING:tensorflow:From <ipython-input-22-897a40b9cd7b>:6: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-22-897a40b9cd7b>:6: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-21-07:57:14
# INFO:tensorflow:Restoring parameters from /tmp\model.ckpt-8000
# INFO:tensorflow:Evaluation [1/1000]
# INFO:tensorflow:Finished evaluation at 2017-07-21-07:57:16
# INFO:tensorflow:Saving dict for global step 8000: accuracy = 1.0, accuracy/baseline_label_mean = 0.43, accuracy/threshold_0.500000_mean = 1.0, auc = 1.0, global_step = 8000, labels/actual_label_mean = 0.43, labels/prediction_mean = 0.429979, loss = 0.00160442, precision/positive_threshold_0.500000_mean = 1.0, recall/positive_threshold_0.500000_mean = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
#
# Test Accuracy: 1.000000
