# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import numpy as np
import pandas as pd
from sklearn import datasets, svm, cross_validation, tree, preprocessing, metrics
import sklearn.ensemble as ske
import tensorflow as tf
# Out:
# C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#from tensorflow.contrib import learn as skflow
#from tensorflow.contrib import skflow
from tensorflow.contrib import learn as skflow #; help(skflow.DNNClassifier.__init__)

# %%
titanic_df = pd.read_excel('titanic3.xls', 'titanic3', index_col=None, na_values=['NA'])

# %%
titanic_df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic_df['survived'].mean()
# Out:
# 0.3819709702062643

# %%
titanic_df.groupby('pclass').mean()
# Out:
#         survived        age     sibsp     parch       fare        body
# pclass
# 1       0.619195  39.159918  0.436533  0.365325  87.508992  162.828571
# 2       0.429603  29.506705  0.393502  0.368231  21.179196  167.387097
# 3       0.255289  24.816367  0.568406  0.400564  13.302889  155.818182

# %%
class_sex_grouping = titanic_df.groupby(['pclass','sex']).mean()
class_sex_grouping
# Out:
#                survived        age     sibsp     parch        fare        body
# pclass sex
# 1      female  0.965278  37.037594  0.555556  0.472222  109.412385         NaN
#        male    0.340782  41.029250  0.340782  0.279330   69.888385  162.828571
# 2      female  0.886792  27.499191  0.500000  0.650943   23.234827   52.000000
#        male    0.146199  30.815401  0.327485  0.192982   19.904946  171.233333
# 3      female  0.490741  22.185307  0.791667  0.731481   15.324250  183.000000
#        male    0.152130  25.962273  0.470588  0.255578   12.415462  151.854167

# %%
class_sex_grouping['survived'].plot.bar()

# %%
group_by_age = pd.cut(titanic_df["age"], np.arange(0, 90, 10))
age_grouping = titanic_df.groupby(group_by_age).mean()
age_grouping['survived'].plot.bar()

# %%
titanic_df.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home.dest     745
# dtype: int64

# %%
titanic_df = titanic_df.drop(['body','cabin','boat'], axis=1)

# %%
titanic_df["home.dest"] = titanic_df["home.dest"].fillna("NA")

# %%
titanic_df = titanic_df.dropna()

# %%
titanic_df.count()
# Out:
# pclass       1043
# survived     1043
# name         1043
# sex          1043
# age          1043
# sibsp        1043
# parch        1043
# ticket       1043
# fare         1043
# embarked     1043
# home.dest    1043
# dtype: int64

# %%
def preprocess_titanic_df(df):
    processed_df = df.copy()
    le = preprocessing.LabelEncoder()
    processed_df.sex = le.fit_transform(processed_df.sex)
    processed_df.embarked = le.fit_transform(processed_df.embarked)
    processed_df = processed_df.drop(['name','ticket','home.dest'],axis=1)
    return processed_df

# %%
processed_df = preprocess_titanic_df(titanic_df)
processed_df
# Out:
#       pclass  survived  sex      age  sibsp  parch      fare  embarked
# 0          1         1    0  29.0000      0      0  211.3375         2
# 1          1         1    1   0.9167      1      2  151.5500         2
# 2          1         0    0   2.0000      1      2  151.5500         2
# 3          1         0    1  30.0000      1      2  151.5500         2
# 4          1         0    0  25.0000      1      2  151.5500         2
# 5          1         1    1  48.0000      0      0   26.5500         2
# 6          1         1    0  63.0000      1      0   77.9583         2
# 7          1         0    1  39.0000      0      0    0.0000         2
# 8          1         1    0  53.0000      2      0   51.4792         2
# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,y,test_size=0.2)

# %% [markdown]
# decidion tree

# %%
clf_dt = tree.DecisionTreeClassifier(max_depth=10)

# %%
clf_dt.fit (X_train, y_train)
clf_dt.score (X_test, y_test)
# Out:
# 0.78468899521531099

# %%
shuffle_validator = cross_validation.ShuffleSplit(len(X), n_iter=20, test_size=0.2, random_state=0)
def test_classifier(clf):
    scores = cross_validation.cross_val_score(clf, X, y, cv=shuffle_validator)
    print("Accuracy: %0.4f (+/- %0.2f)" % (scores.mean(), scores.std()))

# %%
test_classifier(clf_dt)
# Out:
# Accuracy: 0.7756 (+/- 0.02)

# %%
clf_rf = ske.RandomForestClassifier(n_estimators=50)
test_classifier(clf_rf)
# Out:
# Accuracy: 0.7842 (+/- 0.02)

# %%
clf_gb = ske.GradientBoostingClassifier(n_estimators=50)
test_classifier(clf_gb)
# Out:
# Accuracy: 0.8201 (+/- 0.02)

# %%
eclf = ske.VotingClassifier([('dt', clf_dt), ('rf', clf_rf), ('gb', clf_gb)])
test_classifier(eclf)
# Out:
# Accuracy: 0.8041 (+/- 0.02)

# %% [markdown]
# neural Network

# %%
#tf_clf_dnn = skflow.TensorFlowDNNClassifier(hidden_units=[20, 40, 20], n_classes=2, batch_size=256, steps=1000, learning_rate=0.05)
feature_columns = [tf.contrib.layers.real_valued_column("")]
tf_clf_dnn = skflow.DNNClassifier(feature_columns=feature_columns, hidden_units=[20, 40, 20], n_classes=2, model_dir="/tmp")
#tf_clf_dnn.evaluate(batch_size=256, steps=1000)
tf_clf_dnn.fit(X_train, y_train, steps=1000)
accuracy_score = tf_clf_dnn.evaluate(X_test, y_test,steps=1000)["accuracy"]
print("\nTest Accuracy: {0:f}\n".format(accuracy_score))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_master': '', '_save_checkpoints_steps': None, '_task_type': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000017C87F26518>, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': None, '_tf_random_seed': None, '_is_chief': True, '_save_checkpoints_secs': 600, '_evaluation_master': '', '_task_id': 0, '_environment': 'local', '_keep_checkpoint_every_n_hours': 10000, '_num_worker_replicas': 0}
# WARNING:tensorflow:From <ipython-input-26-897a40b9cd7b>:5: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-26-897a40b9cd7b>:5: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# WARNING:tensorflow:From C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp\model.ckpt-1000
# INFO:tensorflow:Saving checkpoints for 1001 into /tmp\model.ckpt.
# INFO:tensorflow:loss = 0.472351, step = 1001
# INFO:tensorflow:global_step/sec: 72.0867
# INFO:tensorflow:loss = 0.465592, step = 1101 (1.400 sec)
# INFO:tensorflow:global_step/sec: 79.1656
# INFO:tensorflow:loss = 0.456485, step = 1201 (1.252 sec)
# INFO:tensorflow:global_step/sec: 82.8278
# INFO:tensorflow:loss = 0.453894, step = 1301 (1.219 sec)
# INFO:tensorflow:global_step/sec: 74.4584
# INFO:tensorflow:loss = 0.44819, step = 1401 (1.333 sec)
# INFO:tensorflow:global_step/sec: 81.4003
# INFO:tensorflow:loss = 0.44417, step = 1501 (1.226 sec)
# INFO:tensorflow:global_step/sec: 85.2123
# INFO:tensorflow:loss = 0.442919, step = 1601 (1.174 sec)
# INFO:tensorflow:global_step/sec: 75.3043
# INFO:tensorflow:loss = 0.446155, step = 1701 (1.330 sec)
# INFO:tensorflow:global_step/sec: 82.5633
# INFO:tensorflow:loss = 0.437241, step = 1801 (1.215 sec)
# INFO:tensorflow:global_step/sec: 72.7068
# INFO:tensorflow:loss = 0.426629, step = 1901 (1.370 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.427085.
# WARNING:tensorflow:From <ipython-input-26-897a40b9cd7b>:6: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-26-897a40b9cd7b>:6: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-17-17:44:54
# INFO:tensorflow:Restoring parameters from /tmp\model.ckpt-2000
# INFO:tensorflow:Evaluation [1/1000]
# INFO:tensorflow:Finished evaluation at 2017-07-17-17:44:56
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.827751, accuracy/baseline_label_mean = 0.397129, accuracy/threshold_0.500000_mean = 0.827751, auc = 0.849206, global_step = 2000, labels/actual_label_mean = 0.397129, labels/prediction_mean = 0.377382, loss = 0.458895, precision/positive_threshold_0.500000_mean = 0.830986, recall/positive_threshold_0.500000_mean = 0.710843
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
#
# Test Accuracy: 0.827751

# %% [markdown]
# def custom_model(X, y):
#     layers = skflow.ops.dnn(X, [20, 40, 20], tf.tanh)
#     return skflow.models.logistic_regression(layers, y)

# %% [markdown]
# #tf_clf_c = skflow.TensorFlowEstimator(model_fn=custom_model, n_classes=2, batch_size=256, steps=1000, learning_rate=0.05)
#
# tf_clf_c = skflow.Estimator(model_fn=custom_model) #n_classes=2)
# tf_clf_c.fit(X_train, y_train, batch_size=256, steps=1000)
# metrics.accuracy_score(y_test, tf_clf_c.predict(X_test))

# %%
passengers_set_1 = titanic_df[titanic_df.pclass == 1].iloc[:20,:].copy()
passengers_set_2 = titanic_df[titanic_df.pclass == 2].iloc[:20,:].copy()
passengers_set_3 = titanic_df[titanic_df.pclass == 3].iloc[:20,:].copy()
passenger_set = pd.concat([passengers_set_1,passengers_set_2,passengers_set_3])
testing_set = preprocess_titanic_df(passenger_set)

# %%
training_set = pd.concat([titanic_df, passenger_set]).drop_duplicates(keep=False)
training_set = preprocess_titanic_df(training_set)

# %%
X_train = training_set.drop(['survived'], axis=1).values
y_train = training_set['survived'].values
X_test = testing_set.drop(['survived'], axis=1).values
y_test = testing_set['survived'].values

# %%
tf_clf_dnn.fit (X_train, y_train,steps=1000)
accuracy_score = tf_clf_dnn.evaluate(X_test, y_test,steps=1000)["accuracy"]
print("\nTest Accuracy: {0:f}\n".format(accuracy_score))
#tf_clf_dnn.score (X_test, y_test)
# Out:
# WARNING:tensorflow:From <ipython-input-30-f4d004ba3a95>:1: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-30-f4d004ba3a95>:1: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# WARNING:tensorflow:From C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp\model.ckpt-2000
# INFO:tensorflow:Saving checkpoints for 2001 into /tmp\model.ckpt.
# INFO:tensorflow:loss = 0.428188, step = 2001
# INFO:tensorflow:global_step/sec: 79.3038
# INFO:tensorflow:loss = 0.421706, step = 2101 (1.260 sec)
# INFO:tensorflow:global_step/sec: 81.4612
# INFO:tensorflow:loss = 0.418903, step = 2201 (1.226 sec)
# INFO:tensorflow:global_step/sec: 74.5419
# INFO:tensorflow:loss = 0.414624, step = 2301 (1.348 sec)
# INFO:tensorflow:global_step/sec: 63.157
# INFO:tensorflow:loss = 0.409107, step = 2401 (1.583 sec)
# INFO:tensorflow:global_step/sec: 72.1622
# INFO:tensorflow:loss = 0.408887, step = 2501 (1.383 sec)
# INFO:tensorflow:global_step/sec: 80.2521
# INFO:tensorflow:loss = 0.409249, step = 2601 (1.249 sec)
# INFO:tensorflow:global_step/sec: 70.0769
# INFO:tensorflow:loss = 0.404548, step = 2701 (1.429 sec)
# INFO:tensorflow:global_step/sec: 73.3527
# INFO:tensorflow:loss = 0.39875, step = 2801 (1.360 sec)
# INFO:tensorflow:global_step/sec: 62.2497
# INFO:tensorflow:loss = 0.400292, step = 2901 (1.603 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into /tmp\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.400512.
# WARNING:tensorflow:From <ipython-input-30-f4d004ba3a95>:2: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-30-f4d004ba3a95>:2: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-17-17:45:40
# INFO:tensorflow:Restoring parameters from /tmp\model.ckpt-3000
# INFO:tensorflow:Evaluation [1/1000]
# INFO:tensorflow:Finished evaluation at 2017-07-17-17:45:42
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.816667, accuracy/baseline_label_mean = 0.483333, accuracy/threshold_0.500000_mean = 0.816667, auc = 0.824249, global_step = 3000, labels/actual_label_mean = 0.483333, labels/prediction_mean = 0.440812, loss = 0.529914, precision/positive_threshold_0.500000_mean = 0.875, recall/positive_threshold_0.500000_mean = 0.724138
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
#
# Test Accuracy: 0.816667

# %%
prediction = tf_clf_dnn.predict(X_test)
passenger_set[passenger_set.survived != prediction]
# Out:
# WARNING:tensorflow:From C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:335: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\dnn.py:422: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# C:\Users\Saumya Suvarna\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Restoring parameters from /tmp\model.ckpt-3000
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 1         1         1                     Allison, Master. Hudson Trevor
# 2         1         0                       Allison, Miss. Helen Loraine
# 3         1         0               Allison, Mr. Hudson Joshua Creighton
# 4         1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5         1         1                                Anderson, Mr. Harry
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 7         1         0                             Andrews, Mr. Thomas Jr
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9         1         0                            Artagaveytia, Mr. Ramon
# 10        1         0                             Astor, Col. John Jacob
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart, Mme. Leontine Pauline
# 13        1         1                       Barber, Miss. Ellen "Nellie"
# 14        1         1               Barkworth, Mr. Algernon Henry Wilson
# 16        1         0                           Baxter, Mr. Quigg Edmond
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18        1         1                              Bazzani, Miss. Albina
# 19        1         0                               Beattie, Mr. Thomson
# 20        1         1                      Beckwith, Mr. Richard Leonard
# 323       2         0                                Abelson, Mr. Samuel
# 324       2         1              Abelson, Mrs. Samuel (Hannah Wizosky)
# 325       2         0                     Aldworth, Mr. Charles Augustus
# 326       2         0                         Andrew, Mr. Edgardo Samuel
# 327       2         0                           Andrew, Mr. Frank Thomas
# 328       2         0                               Angle, Mr. William A
# 329       2         1  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 330       2         0                                    Ashby, Mr. John
# 331       2         0                           Bailey, Mr. Percy Andrew
# 332       2         0                     Baimbrigge, Mr. Charles Robert
# 333       2         1                            Ball, Mrs. (Ada E Hall)
# 334       2         0                      Banfield, Mr. Frederick James
# 335       2         0                         Bateman, Rev. Robert James
# 336       2         1                                  Beane, Mr. Edward
# 337       2         1                  Beane, Mrs. Edward (Ethel Clarke)
# 338       2         0                         Beauchamp, Mr. Henry James
# 339       2         1                          Becker, Master. Richard F
# 340       2         1                        Becker, Miss. Marion Louise
# 341       2         1                       Becker, Miss. Ruth Elizabeth
# 342       2         1   Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 600       3         0                                Abbing, Mr. Anthony
# 601       3         0                      Abbott, Master. Eugene Joseph
# 602       3         0                        Abbott, Mr. Rossmore Edward
# 603       3         1                   Abbott, Mrs. Stanton (Rosa Hunt)
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 606       3         1           Abrahamsson, Mr. Abraham August Johannes
# 607       3         1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
#